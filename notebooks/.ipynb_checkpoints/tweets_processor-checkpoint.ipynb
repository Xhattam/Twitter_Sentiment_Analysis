# %% [markdown]
# ### Extract meaningful info from json

# %%
import json
import pandas as pd
from textblob import TextBlob

# %%
data = json.load(open("../data/raw_tweets_full.json", "r"))

# %%
def get_polarity(score):
    """ Returns a polarity value based on the polarity score (subjective) 
    :param score: polarity score returned by TextBlob 
    :returns: an associated polarity (Positive, Negative, Neutral) """
    if score <= 0.2:
        return "Negative"
    elif score > 0.2 and score <= 0.7:
        return "Neutral"
    else:
        return "Positive"

# %%
def extract_mentions(mentions):
    """ Extract user mentions from a tweet 
    :param mentions: list of user mentions (from Twitter API)
    :returns: comma-separated user name and screen names """
    return ", ".join([e['name'] + " (" + e['screen_name'] + ")" for e in mentions])

# %%
def get_readable_date(twitter_date):
    """ Extract the date in a friendlier format (dd/mm/yy) 
    :param twitter_date: date returned by Twitter API 
    :returns: readable date """
    mapped_months = {'Jan': '01', 'Feb': '02', 'Mar': '03', 'Apr': '04', 'May': '05',
                    'Jun': '06', 'Jul': '07', 'Aug': '08', 'Sep': '09', 'Oct': '10',
                    'Nov': '11', 'Dec': '12'}
    split = twitter_date.split(" ")
    month, value, year = mapped_months[split[1]], split[2], split[-1]
    return "/".join([value, month, year])

# %%
def extract_info(data):
    """ Main extraction function, returns relevant fields for each tweet returned by the 
        Twitter API
    :param data: json file containing the raw extracted tweets 
    :returns: dataframe of extracted information """
    fields = ['u_name', 'u_screen_name', 't_date', 't_text', 't_polarity_score', 
             't_polarity', 't_subjectivity_score', 'u_followers', 't_retweets', 
              't_favorited', 't_mentions']
    all_extracted = {k: [] for k in fields}
    for tweet in data:
        all_extracted['u_name'].append(tweet['user']['name'])
        all_extracted['u_screen_name'].append(tweet['user']['screen_name'])
        all_extracted['t_date'].append(get_readable_date(tweet['created_at']))
        all_extracted['t_text'].append(tweet['full_text'])
        tb_analysed = TextBlob(tweet['full_text'])
        all_extracted['t_polarity_score'].append(tb_analysed.polarity)
        all_extracted['t_subjectivity_score'].append(tb_analysed.sentiment.subjectivity)
        all_extracted['t_polarity'].append(get_polarity(tb_analysed.polarity))
        all_extracted['u_followers'].append(tweet['user']['followers_count'])
        all_extracted['t_retweets'].append(tweet['retweet_count'])
        all_extracted['t_favorited'].append(tweet['favorite_count'])
        all_extracted['t_mentions'].append(extract_mentions(
            tweet['entities']['user_mentions']))
    return pd.DataFrame(all_extracted)

# %%
df = extract_info(data)

# %%
df
# Out:
#                                   u_name    u_screen_name      t_date  \
# 0                        Dr Keith Grimes      keithgrimes  12/03/2019
# 1                            Sam Dowling          saminus  12/03/2019
# 2                        Londonwide LMCs   LondonwideLMCs  12/03/2019
# 3                            Mark Barley      Chronotrope  12/03/2019
# 4                            Mark Barley      Chronotrope  12/03/2019
# 5                          Shaun Lintern     ShaunLintern  12/03/2019
# 6               💣 Medical Devices Expert         JoanneD_  12/03/2019
# 7                                 SHugar       SusiHarris  12/03/2019
# 8                             Meddev Guy       Meddev_guy  12/03/2019
# 9                         michelle drage    michelledrage  12/03/2019
# 10                      Dr Ameen Kamlana         AmeenKam  12/03/2019
# 11                      Global Gene Corp   GlobalGeneCorp  12/03/2019
# 12              💣 Medical Devices Expert         JoanneD_  12/03/2019
# 13              💣 Medical Devices Expert         JoanneD_  12/03/2019
# 14                           Ross Lydall       RossLydall  12/03/2019
# 15                   Georgedigitaldoctor  GeorgeDigitalDr  12/03/2019
# 16                             Dr Murphy       DrMurphy11  12/03/2019
# 17                   Georgedigitaldoctor  GeorgeDigitalDr  12/03/2019
# 18                  Innocent Twizeyimana       RUB1rwanda  12/03/2019
# 19              💣 Medical Devices Expert         JoanneD_  12/03/2019
# 20              💣 Medical Devices Expert         JoanneD_  12/03/2019
# 21              💣 Medical Devices Expert         JoanneD_  12/03/2019
# 22              💣 Medical Devices Expert         JoanneD_  12/03/2019
# 23                      Dr Ameen Kamlana         AmeenKam  12/03/2019
# 24                             Dr Murphy       DrMurphy11  12/03/2019
# 25                             Ben Moody        benpmoody  12/03/2019
# 26                Selvaseelan Selvarajah     DrSelvarajah  12/03/2019
# 27                       Eric Cadesky MD        drcadesky  12/03/2019
# 28                         Darren Larsen     larsendarren  12/03/2019
# 29                                Brinda           thilb2  12/03/2019
# ..                                   ...              ...         ...
# 470  Dr Lea Merone MBChB (hons) MPH&TM Ⓥ        LeaMerone  03/03/2019
# 471                          Dave Triska         dave_dlt  03/03/2019
# 472                          Dave Triska         dave_dlt  03/03/2019
# 473                      Richard Blogger   richardblogger  03/03/2019
# 474              Claire Sutton 💁🏼👜👩🏼‍💻👸🏼    ClaireLSutton  03/03/2019
# 475              Claire Sutton 💁🏼👜👩🏼‍💻👸🏼    ClaireLSutton  03/03/2019
# 476                            Dr Murphy       DrMurphy11  03/03/2019
# 477                          Mark Kelsey        freddy4th  03/03/2019
# 478                      Prof. Steve Cox        gpdiarist  03/03/2019
# 479  Dr Lea Merone MBChB (hons) MPH&TM Ⓥ        LeaMerone  03/03/2019
# 480  Dr Lea Merone MBChB (hons) MPH&TM Ⓥ        LeaMerone  03/03/2019
# 481                     Rowena Christmas  ChristmasRowena  03/03/2019
# 482                          Dave Triska         dave_dlt  03/03/2019
# 483                          Dave Triska         dave_dlt  03/03/2019
# 484                          Dave Triska         dave_dlt  03/03/2019
# 485              Claire Sutton 💁🏼👜👩🏼‍💻👸🏼    ClaireLSutton  03/03/2019
# 486  Dr Lea Merone MBChB (hons) MPH&TM Ⓥ        LeaMerone  03/03/2019
# 487                   Dr Helen Salisbury  HelenRSalisbury  03/03/2019
# 488                          Dave Triska         dave_dlt  03/03/2019
# 489  Dr Lea Merone MBChB (hons) MPH&TM Ⓥ        LeaMerone  03/03/2019
# 490  Dr Lea Merone MBChB (hons) MPH&TM Ⓥ        LeaMerone  03/03/2019
# 491                         Pam oshanter          Pamos19  03/03/2019
# 492                          Colin Brown         colinbro  03/03/2019
# 493              Claire Sutton 💁🏼👜👩🏼‍💻👸🏼    ClaireLSutton  03/03/2019
# 494                      Peter Griffiths   workforcesoton  03/03/2019
# 495                          Dave Triska         dave_dlt  03/03/2019
# 496  Dr Lea Merone MBChB (hons) MPH&TM Ⓥ        LeaMerone  03/03/2019
# 497                          Tony Dexter    GRUMPYCOTTAGE  03/03/2019
# 498                           PharmaFlow    PharmaFlowltd  03/03/2019
# 499              Claire Sutton 💁🏼👜👩🏼‍💻👸🏼    ClaireLSutton  03/03/2019
#
#                                                 t_text  t_polarity_score  \
# 0    @cpeedell @marcus_baw @babylonhealth HI Clive,...          0.450000
# 1    As we near the end of our @LondonwideLMCs annu...          0.200000
# 2    We are now on to our third and final long anti...         -0.012500
# 3    @DrSelvarajah @DrMurphy11 @babylonhealth I mea...         -0.312500
# 4    @DrSelvarajah @DrMurphy11 @babylonhealth I’d l...         -0.100000
# 5    Hosting @babylonhealth GP at Hand app could le...         -0.125000
# 6    @Meddev_guy @DrMurphy11 @babylonhealth @MHRAde...          0.000000
# 7    @vanessafrank3 @kieran_walshe @JonAshworth @ba...          0.700000
# 8    @JoanneD_ @DrMurphy11 @babylonhealth @MHRAdevi...          0.000000
# 9    @RossLydall @LondonwideLMCs @bengoldacre @baby...          0.800000
# 10   @GeorgeDigitalDr @DrSelvarajah @DrMurphy11 @ba...          0.000000
# 11   Find out how leapfrogging technology is improv...          0.000000
# 12   @DrMurphy11 @babylonhealth @MHRAdevices @RCPLo...         -0.500000
# 13   @GeorgeDigitalDr @DrSelvarajah @DrMurphy11 @ba...         -0.050000
# 14   “Brave” opening to @LondonwideLMCs GPs confere...          0.050000
# 15   @DrSelvarajah @DrMurphy11 @babylonhealth Oh an...         -0.008929
# 16   @DrSelvarajah @babylonhealth As Medical Direct...          0.066667
# 17   @DrSelvarajah @DrMurphy11 @babylonhealth Genui...          0.216667
# 18   @babylrwanda \nI think many would love to try ...          0.500000
# 19   @DrSelvarajah @keithgrimes @Pamos19 @iDrSunny ...          0.000000
# 20   @DrSelvarajah @keithgrimes @Pamos19 @iDrSunny ...          0.600000
# 21   @DrSelvarajah @keithgrimes @Pamos19 @iDrSunny ...          0.150000
# 22   @DrSelvarajah @DrMurphy11 @babylonhealth Ask t...          0.366667
# 23   @DrSelvarajah @DrMurphy11 @babylonhealth The q...          0.000000
# 24   @drcadesky @larsendarren @CBCEricRankin @Docto...          0.000000
# 25   Pleasure to meet @babylonhealth and @Sleepio y...          0.350000
# 26   @DrMurphy11 @babylonhealth Babylon medical dir...          0.000000
# 27   @larsendarren @CBCEricRankin @DoctorsOfBC @bab...          0.000000
# 28   @drcadesky @CBCEricRankin @DoctorsOfBC @babylo...          0.000000
# 29   @DrMurphy11 @trishgreenhalgh @meloncarrier @ba...          0.000000
# ..                                                 ...               ...
# 470  @ClaireLSutton @dave_dlt @DrMurphy11 @babylonh...         -0.125000
# 471  @DrMurphy11 @LeaMerone @babylonhealth @ClaireL...          0.000000
# 472  @ClaireLSutton @LeaMerone @DrMurphy11 @babylon...          0.245040
# 473  @NHSCCIO @babylonhealth @DrMurphy11 @behr_dr @...          0.000000
# 474  @LeaMerone @dave_dlt @DrMurphy11 @babylonhealt...          0.000000
# 475  @LeaMerone @dave_dlt @DrMurphy11 @babylonhealt...         -0.033333
# 476  @LeaMerone @dave_dlt @babylonhealth @ClaireLSu...         -0.283333
# 477  @NHSCCIO @babylonhealth @DrMurphy11 @behr_dr @...          0.005682
# 478  @kirstybaldwin3 Piles Algorithms need some wor...          0.000000
# 479  @ClaireLSutton @dave_dlt @DrMurphy11 @babylonh...          0.250000
# 480  @dave_dlt @ClaireLSutton @DrMurphy11 @babylonh...          0.333333
# 481  @HelenRSalisbury @babylonhealth The questions ...          0.000000
# 482  @babylonhealth @DrMurphy11 Cheers guys! Look f...          0.000000
# 483  @LeaMerone @ClaireLSutton @DrMurphy11 @babylon...          0.000000
# 484  @LeaMerone @ClaireLSutton @DrMurphy11 @babylon...          0.000000
# 485  @dave_dlt @LeaMerone @DrMurphy11 @babylonhealt...          0.700000
# 486  @dave_dlt @ClaireLSutton @DrMurphy11 @babylonh...          0.001250
# 487  There's a pattern to the flaws in the useless ...         -0.247917
# 488  @LeaMerone @ClaireLSutton @DrMurphy11 @babylon...          0.525000
# 489  @dave_dlt @ClaireLSutton @DrMurphy11 @babylonh...          0.000000
# 490  @dave_dlt @ClaireLSutton @DrMurphy11 @babylonh...          0.078356
# 491  @ManeeshJuneja @DrMurphy11 "You can't pay for ...          0.000000
# 492  @psmedic @marcus_baw @NHSCCIO @babylonhealth @...          0.091667
# 493  @LeaMerone @dave_dlt @DrMurphy11 @babylonhealt...          0.233333
# 494  @babylonhealth @GPatHand .@gpathand looks like...          0.435000
# 495  @LeaMerone @ClaireLSutton @DrMurphy11 @babylon...          0.000000
# 496  @ClaireLSutton @dave_dlt @DrMurphy11 @babylonh...          0.625000
# 497  @NHSCCIO @babylonhealth @DrMurphy11 @behr_dr @...          0.000000
# 498  @NHSCCIO @behr_dr @babylonhealth @DrMurphy11 @...         -0.083333
# 499  @LeaMerone @dave_dlt @DrMurphy11 @babylonhealt...          0.000000
#
#     t_polarity  t_subjectivity_score  u_followers  t_retweets  t_favorited  \
# 0      Neutral              0.700000         5499           0            1
# 1     Negative              0.341667         1417           2            3
# 2     Negative              0.350000         2076           1            1
# 3     Negative              0.687500          353           0            0
# 4     Negative              0.100000          353           0            1
# 5     Negative              0.375000        24674           3            3
# 6     Negative              0.000000          466           0            0
# 7      Neutral              0.600000           48           0            0
# 8     Negative              0.000000            8           0            0
# 9     Positive              1.000000         3646           0            2
# 10    Negative              1.000000         1418           0            2
# 11    Negative              0.000000          299           1            1
# 12    Negative              0.300000          466           1            1
# 13    Negative              0.425000          466           0            2
# 14    Negative              0.733333        10883           2            1
# 15    Negative              0.325893           83           0            1
# 16    Negative              0.205556         4052           2            1
# 17     Neutral              0.375000           83           0            1
# 18     Neutral              0.550000           92           0            0
# 19    Negative              0.000000          466           1            0
# 20     Neutral              0.800000          466           1            0
# 21    Negative              0.391667          466           1            1
# 22     Neutral              0.766667          466           0            1
# 23    Negative              0.000000         1418           0            2
# 24    Negative              0.000000         4052           0            1
# 25     Neutral              0.600000         1147           0            7
# 26    Negative              0.000000          412           2            7
# 27    Negative              0.000000         2799           0            1
# 28    Negative              0.000000         2472           0            0
# 29    Negative              0.000000          348           0            1
# ..         ...                   ...          ...         ...          ...
# 470   Negative              0.500000          805           0            1
# 471   Negative              0.000000          338           0            0
# 472    Neutral              0.468651          338           0            1
# 473   Negative              0.000000         4138           0            5
# 474   Negative              0.000000          468           0            1
# 475   Negative              0.391667          468           0            1
# 476   Negative              0.383333         4052           0            1
# 477   Negative              0.414773          577           1            5
# 478   Negative              0.000000          113           0            0
# 479    Neutral              0.300000          805           0            1
# 480    Neutral              0.583333          805           0            1
# 481   Negative              0.000000          610           0            0
# 482   Negative              0.000000          338           0            0
# 483   Negative              0.000000          338           0            1
# 484   Negative              0.000000          338           0            1
# 485    Neutral              0.850000          468           0            2
# 486   Negative              0.300833          805           0            0
# 487   Negative              0.283333         2405           4            7
# 488    Neutral              0.441667          338           0            0
# 489   Negative              0.000000          805           0            1
# 490   Negative              0.549074          805           0            0
# 491   Negative              1.000000          960           0            1
# 492   Negative              0.419444          194           1            8
# 493    Neutral              0.500000          468           0            1
# 494    Neutral              0.710000         2852           0            0
# 495   Negative              0.000000          338           0            1
# 496    Neutral              0.888889          805           0            1
# 497   Negative              0.000000          490           0            0
# 498   Negative              0.402778           22           0            1
# 499   Negative              0.616667          468           0            2
#
#                                             t_mentions
# 0    Clive Peedell (cpeedell), Dr Marcus Baw (marcu...
# 1    Londonwide LMCs (LondonwideLMCs), Jackieappleb...
# 2    Elliott (ElliottSinger), Jackieapplebeeturner ...
# 3    Selvaseelan Selvarajah (DrSelvarajah), Dr Murp...
# 4    Selvaseelan Selvarajah (DrSelvarajah), Dr Murp...
# 5    Babylon (babylonhealth), Ben Heather (BHeather...
# 6    Meddev Guy (Meddev_guy), Dr Murphy (DrMurphy11...
# 7    vanessa frank (vanessafrank3), Kieran Walshe (...
# 8    Medical Devices Expert 🎳 (JoanneD_), Dr Murphy...
# 9    Ross Lydall (RossLydall), Londonwide LMCs (Lon...
# 10   Georgedigitaldoctor (GeorgeDigitalDr), Selvase...
# 11   Babylon (babylonhealth), babyl Rwanda (babylrw...
# 12   Dr Murphy (DrMurphy11), Babylon (babylonhealth...
# 13   Georgedigitaldoctor (GeorgeDigitalDr), Selvase...
# 14   Londonwide LMCs (LondonwideLMCs), ben goldacre...
# 15   Selvaseelan Selvarajah (DrSelvarajah), Dr Murp...
# 16   Selvaseelan Selvarajah (DrSelvarajah), Babylon...
# 17   Selvaseelan Selvarajah (DrSelvarajah), Dr Murp...
# 18   babyl Rwanda (babylrwanda), Babylon (babylonhe...
# 19   Selvaseelan Selvarajah (DrSelvarajah), Dr Keit...
# 20   Selvaseelan Selvarajah (DrSelvarajah), Dr Keit...
# 21   Selvaseelan Selvarajah (DrSelvarajah), Dr Keit...
# 22   Selvaseelan Selvarajah (DrSelvarajah), Dr Murp...
# 23   Selvaseelan Selvarajah (DrSelvarajah), Dr Murp...
# 24   Eric Cadesky MD (drcadesky), Darren Larsen (la...
# 25   Babylon (babylonhealth), Sleepio (Sleepio), NH...
# 26   Dr Murphy (DrMurphy11), Babylon (babylonhealth...
# 27   Darren Larsen (larsendarren), Eric P Rankin (C...
# 28   Eric Cadesky MD (drcadesky), Eric P Rankin (CB...
# 29   Dr Murphy (DrMurphy11), Trisha Greenhalgh #Peo...
# ..                                                 ...
# 470  Claire Sutton 💁🏼👜👩🏼‍💻👸🏼 (ClaireLSutton), Dave ...
# 471  Dr Murphy (DrMurphy11), Dr Lea Merone MBChB (h...
# 472  Claire Sutton 💁🏼👜👩🏼‍💻👸🏼 (ClaireLSutton), Dr Le...
# 473  Simon Eccles (NHSCCIO), Babylon (babylonhealth...
# 474  Dr Lea Merone MBChB (hons) MPH&TM Ⓥ (LeaMerone...
# 475  Dr Lea Merone MBChB (hons) MPH&TM Ⓥ (LeaMerone...
# 476  Dr Lea Merone MBChB (hons) MPH&TM Ⓥ (LeaMerone...
# 477  Simon Eccles (NHSCCIO), Babylon (babylonhealth...
# 478  Kirsty Baldwin (kirstybaldwin3), Babylon (baby...
# 479  Claire Sutton 💁🏼👜👩🏼‍💻👸🏼 (ClaireLSutton), Dave ...
# 480  Dave Triska (dave_dlt), Claire Sutton 💁🏼👜👩🏼‍💻👸...
# 481  Dr Helen Salisbury (HelenRSalisbury), Babylon ...
# 482    Babylon (babylonhealth), Dr Murphy (DrMurphy11)
# 483  Dr Lea Merone MBChB (hons) MPH&TM Ⓥ (LeaMerone...
# 484  Dr Lea Merone MBChB (hons) MPH&TM Ⓥ (LeaMerone...
# 485  Dave Triska (dave_dlt), Dr Lea Merone MBChB (h...
# 486  Dave Triska (dave_dlt), Claire Sutton 💁🏼👜👩🏼‍💻👸...
# 487                            Babylon (babylonhealth)
# 488  Dr Lea Merone MBChB (hons) MPH&TM Ⓥ (LeaMerone...
# 489  Dave Triska (dave_dlt), Claire Sutton 💁🏼👜👩🏼‍💻👸...
# 490  Dave Triska (dave_dlt), Claire Sutton 💁🏼👜👩🏼‍💻👸...
# 491  Digital Health Futurist 👨‍💻 (ManeeshJuneja), D...
# 492  Dr Pranev Sharma (psmedic), Dr Marcus Baw (mar...
# 493  Dr Lea Merone MBChB (hons) MPH&TM Ⓥ (LeaMerone...
# 494  Babylon (babylonhealth), Babylon GP at hand (G...
# 495  Dr Lea Merone MBChB (hons) MPH&TM Ⓥ (LeaMerone...
# 496  Claire Sutton 💁🏼👜👩🏼‍💻👸🏼 (ClaireLSutton), Dave ...
# 497  Simon Eccles (NHSCCIO), Babylon (babylonhealth...
# 498  Simon Eccles (NHSCCIO), Dr Jon Behr (behr_dr),...
# 499  Dr Lea Merone MBChB (hons) MPH&TM Ⓥ (LeaMerone...
#
# [500 rows x 11 columns]

# %%
df.to_csv("../data/dataframe_formatted_results.csv")  # saving to csv
