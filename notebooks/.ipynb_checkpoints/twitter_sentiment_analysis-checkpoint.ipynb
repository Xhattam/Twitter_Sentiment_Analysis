# %%
import re
import tweepy
from tweepy import OAuthHandler
import json
from monkeylearn import MonkeyLearn
from textblob import TextBlob

# %%
class TwitterClient(object):
    def __init__(self):
        keys = json.load(open("../data/twitter_keys.json", "r"))
        consumer_key = keys['consumer_key']
        consumer_secret = keys['consumer_secret']
        acces_token = keys['access_token']
        access_token_secret = keys['access_token_secret']
        
        try:
            self.auth = OAuthHandler(consumer_key, consumer_secret)
            self.auth.set_access_token(acces_token, access_token_secret)
            self.api = tweepy.API(self.auth)
        except:
            print("Authentication failed")
            
    def get_raw_tweets(self, query, count = 10): 
        ''' 
        Main function to fetch tweets and parse them. 
        '''
        # empty list to store parsed tweets 
        tweets = set([]) 
        try: 
            # call twitter api to fetch tweets 
            fetched_tweets = self.api.search(q=query, count=count, lang='en') 
            for tweet in fetched_tweets:
                tweets.add(tweet.text)
            return list(tweets) 
        
        except tweepy.TweepError as e: 
            # print error (if any) 
            print("Error : " + str(e))

# %%
class SentimentAnalyser:
    
    def __init__(self, tweets):
        self.tweets = tweets
        self.keys = json.load(open("../data/twitter_keys.json", "r"))
        self.monkey_model = MonkeyLearn(self.keys['monkey_api_key'])
    
    def analyse_tweets(self):
        return self.monkey_model.classifiers.classify(self.keys['model_id'], self.tweets)
    
    def get_polarity(self, tweet):
        return TextBlob(tweet).polarity
    
    def get_tb_sentiment(self, tweet):
        return TextBlob(tweet).sentiment

# %%
tc = TwitterClient()

# %%
tweets = tc.get_raw_tweets("babylon health", count=100)

# %%
sa = SentimentAnalyser(tweets)

# %%
r = sa.analyse_tweets()

# %%
r.body
# Out:
# [{'text': 'RT @PrivacyMatters: I saw this Ad on the tube for Babylon Health GP app. So, I took a quick look. FIVE embedded trackers - Facebook Login,…',
#   'external_id': None,
#   'error': False,
#   'classifications': [{'tag_name': 'Neutral',
#     'tag_id': 60333050,
#     'confidence': 0.941}]},
#  {'text': 'RT @drbenwhite: Five embedded trackers when you sign up to the Babylon health app. @bengoldacre  https://t.co/BjGN29crdj',
#   'external_id': None,
#   'error': False,
#   'classifications': [{'tag_name': 'Neutral',
#     'tag_id': 60333050,
#     'confidence': 0.915}]},
#  {'text': 'RT @kieran_walshe: This does not look good. According to this tech jobs website, @babylonhealth HR staff have been posting fake reviews of…',
#   'external_id': None,
#   'error': False,
#   'classifications': [{'tag_name': 'Negative',
#     'tag_id': 60333049,
#     'confidence': 0.941}]}]

# %%
for e in r.body:
    print(e['text'])
    print("Polarity", sa.get_polarity(e['text']))
    print("TB sentiment", sa.get_tb_sentiment(e['text']))
    for elem in e['classifications']:        
        print(elem['tag_name'], elem['confidence'])
    print("-" * 20)
# Out:
# Babylon's @paul_bate talking about the potential of AI in primary care at today's Lexington Health Local event… https://t.co/ZHP3wWTC64
# Polarity 0.13333333333333333
# TB sentiment Sentiment(polarity=0.13333333333333333, subjectivity=0.5)
# Neutral 0.875
# --------------------
# How do you build an effective go-to-market organization in a #B2B environment? Following on from a breakfast event… https://t.co/3pG3qVELsT
# Polarity 0.3
# TB sentiment Sentiment(polarity=0.3, subjectivity=0.45)
# Neutral 0.781
# --------------------
# This does not look good. According to this tech jobs website, @babylonhealth HR staff have been posting fake review… https://t.co/s5YMJkcAPn
# Polarity 0.09999999999999998
# TB sentiment Sentiment(polarity=0.09999999999999998, subjectivity=0.8)
# Negative 0.693
# --------------------
# RT @drbenwhite: Five embedded trackers when you sign up to the Babylon health app. @bengoldacre  https://t.co/BjGN29crdj
# Polarity 0.0
# TB sentiment Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral 0.915
# --------------------
# @AnnettePriest @wickedgeekie well howdy back! I'll be out for a week on the 4th and am there to hire designers and… https://t.co/KCP2fscMOt
# Polarity 0.0
# TB sentiment Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral 0.584
# --------------------
# RT @DrMurphy11: A 56yr old self-employed 20/day smoker is coughing up blood, losing weight &amp; fears he could have lung cancer.
#
# He uses the…
# Polarity 0.1
# TB sentiment Sentiment(polarity=0.1, subjectivity=0.2)
# Neutral 0.764
# --------------------
# Paul Bate from Babylon Health introducing us to Babylon's mission https://t.co/kYrRD2D38g
# Polarity 0.0
# TB sentiment Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral 0.911
# --------------------
# Five embedded trackers when you sign up to the Babylon health app. @bengoldacre  https://t.co/BjGN29crdj
# Polarity 0.0
# TB sentiment Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral 0.911
# --------------------
# RT @kieran_walshe: This does not look good. According to this tech jobs website, @babylonhealth HR staff have been posting fake reviews of…
# Polarity 0.09999999999999998
# TB sentiment Sentiment(polarity=0.09999999999999998, subjectivity=0.8)
# Negative 0.941
# --------------------
# RT @DrMurphy11: "A Sinking Ship - Fake reviews by Management" @babylonhealth #Glassdoor review Feb 2019.
#
# @CareQualityComm @MHRAdevices @Ma…
# Polarity -0.5
# TB sentiment Sentiment(polarity=-0.5, subjectivity=1.0)
# Neutral 0.901
# --------------------
# SPRING MEAL PREP
#
# Courtesy of: Total Health Wellness Center:
# Dr. Frank Gomez, Chiropractic Physician
# 4844 Sunrise… https://t.co/T1xrbZmFhO
# Polarity -0.05
# TB sentiment Sentiment(polarity=-0.05, subjectivity=0.425)
# Neutral 0.824
# --------------------
# .@BupaUK offers the benefits of Babylon’s artificial intelligence I  Bupa business client, employees can have fast… https://t.co/bSqDsQvpUI
# Polarity -0.25
# TB sentiment Sentiment(polarity=-0.25, subjectivity=0.5)
# Neutral 0.719
# --------------------
# RT @GedeonIbrahim: With Ali Parsa CEO of Babylon, transforming health care and better health outcomes globally.
#
# Be well. https://t.co/LE2…
# Polarity 0.25
# TB sentiment Sentiment(polarity=0.25, subjectivity=0.25)
# Neutral 0.65
# --------------------
# With Ali Parsa CEO of Babylon, transforming health care and better health outcomes globally.
#
# Be well. https://t.co/LE2JhQ0Q2A
# Polarity 0.25
# TB sentiment Sentiment(polarity=0.25, subjectivity=0.25)
# Neutral 0.609
# --------------------
# @creargachas it's so tempting... also just, I've also been blasting through trying to get there but one of my frien… https://t.co/l42iNWXTeo
# Polarity 0.0
# TB sentiment Sentiment(polarity=0.0, subjectivity=0.0)
# Negative 0.433
# --------------------
# RT @threadreaderapp: @Pamos19 Saluti you can read it here: Thread by @PrivacyMatters: "I saw this Ad on the tube for Babylon Health GP app.…
# Polarity 0.0
# TB sentiment Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral 0.937
# --------------------
# Paul Bate from Babylon Health explains how Babylon's AI was built to mimic a doctor's brain. #LexHealthEvents https://t.co/O89u79f95P
# Polarity 0.0
# TB sentiment Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral 0.88
# --------------------
# RT @HI_Daily: .@BupaUK offers the benefits of Babylon’s artificial intelligence I  Bupa business client, employees can have fast access to…
# Polarity -0.09999999999999999
# TB sentiment Sentiment(polarity=-0.09999999999999999, subjectivity=0.5333333333333333)
# Neutral 0.7
# --------------------
# @jappleby123 @kieran_walshe @babylonhealth Looking at the @Glassdoor reviews, there is a worrying theme.
#
# "Toxic &amp;… https://t.co/i08XAfwmBI
# Polarity 0.0
# TB sentiment Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral 0.704
# --------------------
# RT @DrMurphy11: @jappleby123 @kieran_walshe @babylonhealth Looking at the @Glassdoor reviews, there is a worrying theme.
#
# "Toxic &amp; Inept Ma…
# Polarity 0.0
# TB sentiment Sentiment(polarity=0.0, subjectivity=0.0)
# Negative 0.601
# --------------------
# RT @msjaneaustin: @thedailyem I'm hiring for the babylon Austin office and I'll be out for a week from the 4th. I'll be talking at event to…
# Polarity 0.0
# TB sentiment Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral 0.829
# --------------------
# RT @PrivacyMatters: I saw this Ad on the tube for Babylon Health GP app. So, I took a quick look. FIVE embedded trackers - Facebook Login,…
# Polarity 0.3333333333333333
# TB sentiment Sentiment(polarity=0.3333333333333333, subjectivity=0.5)
# Neutral 0.941
# --------------------
# RT @DrMurphy11: In 2017, Babylon Health claimed their Chatbot was '100%' safe.
#
# In 2018, Babylon Health claimed their Chatbot could 'diagno…
# Polarity 0.5
# TB sentiment Sentiment(polarity=0.5, subjectivity=0.5)
# Negative 0.507
# --------------------
# It’s no secret that artificial intelligence, or AI, technology is changing the #world, but many would be wary to co… https://t.co/0uZkPW6pVm
# Polarity -0.09999999999999999
# TB sentiment Sentiment(polarity=-0.09999999999999999, subjectivity=0.7250000000000001)
# Neutral 0.548
# --------------------
# RT @LexHealth: Babylon's @paul_bate talking about the potential of AI in primary care at today's Lexington Health Local event #LexHealthEve…
# Polarity 0.13333333333333333
# TB sentiment Sentiment(polarity=0.13333333333333333, subjectivity=0.5)
# Neutral 0.884
# --------------------
# @eleanorbartosh @dominiccampbell Hello! Thank you Dominic. Eleanor I work at Babylon health and we are opening our… https://t.co/WosfFSvyWf
# Polarity 0.0
# TB sentiment Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral 0.556
# --------------------
# @thedailyem I'm hiring for the babylon Austin office and I'll be out for a week from the 4th. I'll be talking at ev… https://t.co/gI2tZKaDPu
# Polarity 0.0
# TB sentiment Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral 0.76
# --------------------
