# %%
import pandas as pd

# %%
vader = pd.read_csv("/home/jessica/Self_Teaching/Self/BigProjects/tweets_sentiment_analysis/TwitterSentimentAnalysis_Project/outputs/dataframe_results_2232019_16:0.csv")

# %%
vader.head()
len(vader)
# Out:
# 208

# %%
neg_vader = vader.loc[(vader['t_polarity'] == "Negative")]
len(neg_vader)
# Out:
# 34

# %%
neg_murphy = vader.loc[(vader['t_polarity'] == "Positive") & (vader['u_screen_name'] == "DrMurphy11")]

# %%
neg_vader
# Out:
#      Unnamed: 0                       u_name    u_screen_name      t_date  \
# 2             2                 Jeremy Hoare   TopTVCameraman  22/03/2019
# 9             9                   ian newell       iannewell7  21/03/2019
# 16           16                         Teri    TeriOsteopath  21/03/2019
# 22           22                    Dr Murphy       DrMurphy11  21/03/2019
# 28           28                    Dr Murphy       DrMurphy11  20/03/2019
# 38           38              Adrian Adewunmi   AdrianAdewunmi  20/03/2019
# 53           53         Dr Kenny Livingstone      Doctorkenny  19/03/2019
# 63           63                     Dr. Mike       EmergMedDr  19/03/2019
# 66           66     Joanne Clements #NHSLove      joannekarma  19/03/2019
# 67           67            Jose Miguel Cacho  josemiguelcacho  19/03/2019
# 82           82             Dr Pranev Sharma          psmedic  18/03/2019
# 86           86                    Dr Murphy       DrMurphy11  18/03/2019
# ...

# %%
for t in neg_murphy['t_text']:
    print(t)
    print("-" * 20)
# Out:
# The @babylonhealth Feedback page talked of 'genuine' 'transparency' &amp; claimed they would upload all rating relating to the service.
#
# However, it appears that wasn't actually true, &amp; after being challenged, the website is now amended.
#
# Before 👇                    After 👇 https://t.co/foltQMguwV
# --------------------
# Dear @GPatHand
#
# Your website is very misleading, as you have used Trust Pilot ratings for @babylonhealth (Private Healthcare) to promote @GPatHand (NHS Healthcare).
#
# There are 'no' @Trustpilot reviews for GP at Hand, hence this is highly misleading.
#
# Can you please amend this. https://t.co/swa3nr9uaI
# --------------------
# Dear @babylonhealth
#
# If "the start of any genuine feedback relationship is transparency" &amp; you claim to be "uploading all the in-app ratings... &amp; all the things you’ve told us about the service..."
#
# Then why are only positive 5* reviews mentioned here👇?  https://t.co/x2F0v40T6z
# --------------------
# ...

# %%
neg_murphy
# Out:
#      Unnamed: 0     u_name u_screen_name      t_date  \
# 5             5  Dr Murphy    DrMurphy11  22/03/2019
# 27           27  Dr Murphy    DrMurphy11  20/03/2019
# 32           32  Dr Murphy    DrMurphy11  20/03/2019
# 158         158  Dr Murphy    DrMurphy11  15/03/2019
#
#                                                 t_text  t_polarity_score  \
# 5    The @babylonhealth Feedback page talked of 'ge...          0.375000
# 27   Dear @GPatHand\n\nYour website is very mislead...          0.120000
# 32   Dear @babylonhealth \n\nIf "the start of any g...          0.209091
# 158  @doctorsdilemma @bengoldacre @babylonhealth Wh...          0.100000
#
#     t_polarity  t_subjectivity_score  u_followers  t_retweets  t_favorited  \
# 5     Positive              0.575000         4091           2            4
# 27    Positive              0.405000         4091           8           12
# 32    Positive              0.681818         4091           5           11
# ...
