# %%
import pandas as pd

# %%
vader = pd.read_csv("/home/jessica/Self_Teaching/Self/BigProjects/tweets_sentiment_analysis/TwitterSentimentAnalysis_Project/outputs/dataframe_results_2232019_9:36.csv")

# %%
textblob = pd.read_csv(
    "/home/jessica/Self_Teaching/Self/BigProjects/tweets_sentiment_analysis/TwitterSentimentAnalysis_Project/outputs/dataframe_results_2232019_9:33.csv")

# %%
vader.head()
# Out:
#    Unnamed: 0            u_name u_screen_name      t_date  \
# 0           0     Andrew Turner   andykturner  22/03/2019
# 1           1         Dr Murphy    DrMurphy11  22/03/2019
# 2           2        WillyWhite  ooWillyWhite  21/03/2019
# 3           3            Andrew      rooo_210  21/03/2019
# 4           4  Prakash Kachhala    pkonline84  21/03/2019
#
#                                               t_text  t_polarity_score  \
# 0  @felly500 @MattHancock It's all a bit product-...          0.000000
# 1  The @babylonhealth Feedback page talked of 'ge...          0.375000
# 2  @babylonhealth Would love to Babylon pair up w...          0.500000
# 3  @pkonline84 @MattHancock @babylonhealth A Heal...         -0.033333
# 4  Maybe @MattHancock could have contacted @babyl...          0.000000
#
#   t_polarity  t_subjectivity_score  u_followers  t_retweets  t_favorited  \
# 0   Negative              0.000000          476           0            0
# ...

# %%
neg_vader = vader.loc[vader['t_polarity'] == "Negative"]
len(neg_vader)
# Out:
# 54

# %%
for t in neg_vader['t_text']:
    print(t)
    print("-" * 20)
# Out:
# @felly500 @MattHancock It's all a bit product-placementy again too isn't it, like his @babylonhealth sales pitch. Dubious ethics.
# --------------------
# The @babylonhealth Feedback page talked of 'genuine' 'transparency' &amp; claimed they would upload all rating relating to the service.
#
# However, it appears that wasn't actually true, &amp; after being challenged, the website is now amended.
#
# Before 👇                    After 👇 https://t.co/foltQMguwV
# --------------------
# @pkonline84 @MattHancock @babylonhealth A Health Secretary who is actively trying to promote discord between doctors and nurses, whilst undermining his doctor workforce. Plus his 15% risk of prostate cancer is less than the 18% lifetime risk 🤨🙄 What an absolute FOOL
# --------------------
# Maybe @MattHancock could have contacted @babylonhealth for a virtual rectal examination. #nhs
#
# BBC News - Hancock criticised over DNA test 'over reaction'
# https://t.co/cXzdHxmqI4
# --------------------
# ...
